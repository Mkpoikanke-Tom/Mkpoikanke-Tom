# %% [markdown]
# <a href="https://colab.research.google.com/github/Mkpoikanke-Tom/Mkpoikanke-Tom/blob/main/Variables_and_data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Variable
# A variable can be referred to as a name used to store a value or list of values so that it can be used later.
#   ##  Type of variables
#
# * int
# * float
# * string
# * boolean

# %%
## Create a code cell to showcase how variable works, this involves all variable types

name = "Tom"
age = 26
cgpa = 4.74
is_student = True
print(name)
print(age)
# Out:
# Tom
# 26

# %%
## The variables here are the student_name, Institution, Age, Qualification and  Is_student which stores the values inform of a string,
## int and boolean value

Student_name  = "Emmanuel"
Institution = "University of Portharcourt"
Age = 28
Qualification = "Bachelor of Science"
Is_student =  True
print(Student_name)
print(Institution)
print(Age)
print(Qualification)
print(Is_student)
# Out:
# Emmanuel
# University of Portharcourt
# 28
# Bachelor of Science
# True

# %% [markdown]
# # **Lesson learnt are;**
# variables stores values, for example in the variable called "Qualification", we see that the value stored in it was "Bachelor of Science".
#  We also see that strings uses quotation marks for example the value of qualification was "Bachelor of Science", which shows that the variable qualification stores a string as its value. Also the variable "Age" stores an integer as its value, from the code above the value of age is 26, then the boolean values can only be True or False, for instance from the code above the variable named Is_student has a boolean as its value then lastly the Float point number has its form as a decimal number,  for instance the variable named cgpa has a float number know to be a decimal number as its value.
#
# ## NOTE:
# * Variable stores values.
# * String use quotation mark.
# * Integers which are numbers does not use quotation marks.
# * Booleans can only be True or False also the first letter of a boolean values should be capitalized.
# * Float numbers are decimal numbers for example 5.00.

# %%
## Checking the type of variables from the code below

name = "Mkpoikanke"
age = 26
cgpa = 4.74
is_student = True
print(type(name))
print(type(age))
print(type(cgpa))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
## A variable created that stores information about the user

first_name = "Mkpoikanke"
last_name = "Tom"
age = 26
institution = "Bowen University"
department = "Mathematics and statistics department "
cgpa = 5.00
is_final_year = False
print(first_name)
print(last_name)
print(age)
print(institution)
print(department)
print(institution)
print(cgpa)
print(is_final_year)
# Out:
# Mkpoikanke
# Tom
# 26
# Bowen University
# Mathematics and statistics department
# Bowen University
# 5.0
# False

# %%
## Create a variable for a bank customer
##Note a formatted string has been used while tring to print the currency sign

customer_name = "Brooks"
account_number = 6025827669
account_balance = 45000.0
is_active = True
print(customer_name)
print(account_number)
print(f"\u20A6{account_balance}")
print(is_active)
# Out:
# Brooks
# 6025827669
# ₦45000.0
# True

# %%
##More practice on variables but this time using formatted string not just printed as normal variables
## Create a variable for a student

student_name = "Emmanuel"
matric_no = "BU24SEN1003"
department = "Software Engineering"
level = 300
cgpa = 4.98
has_paid_fees = True
print(f"Name: {student_name}")
print(f"Matric Number: {matric_no}")
print(f"Department: {department}")
print(f"Level: {level}")
print(f"CGPA: {cgpa}")
print(f"Fees Paid: {has_paid_fees}")
# Out:
# Name: Emmanuel
# Matric Number: BU24SEN1003
# Department: Software Engineering
# Level: 300
# CGPA: 4.98
# Fees Paid: True

# %%
## Variable Naming Rules
# 1. Variable names can contain letters, numbers and underscores(_).
# 2. Variable names cannot start with a number for instance "2age"
# 3. Variable names cannot spaces.
# 4. Variable names are case sensitive
# 5. A python keyword is not to be used as a variable name.
# 6. Use meaningful names

## some reserved keywords in python which cannot be used as  variable names  are if, elif, else, for,  while, class, def, return, import, True, False and None

# %% [markdown]
# ## Re-assigning Variables:
#  A variable can change it value during the excution of a program, for example the value of the variable called name was mkpoikanke then the same variable is is assigned a new value which replaces the old one as Elisha, if we print the variable name what come up as the output becomes the new value. This means the new value of the variable replaces the old one.So this is to say that a variable reassignment overwrites the previous value stored in the variable if not printed because the variable is assigned to another value, that is python displays the most recent value because the previous value has been overwritten.

# %%
##Write a python program to showcase this

name = "Mkpoikanke"
name = "Elisha"
print(name)
# Out:
# Elisha

# %%
##Another example of a variable re-assignment is the code below

name = "Tom"
age = 25
print(name)
age = 45
name ="Daniel"
print(age)
print(name)
# Out:
# Tom
# 45
# Daniel

# %%
## Muliple assignment example

x, y = 3, 2
print(x)
print(y)
# Out:
# 3
# 2

# %%
##What if we had something like
x,y = 26, 54
x,y =y,x
print(x)
print(y)
# Out:
# 54
# 26

# %%
#Another example of multiple assignments
first, second = "Python", "Data Analysis"
print(second)
print(first)
# Out:
# Data Analysis
# Python

# %% [markdown]
# ## Dynamic Typing:
# In python variables can change not only its values but data types.This is an important concept to realize in python because other programming languages like java an c++ does not do same because the are statistically typed. So dynamic typing is a feature in python where a variable can store different type of data at different times during the excution of a program, this is to say that python automatically detects the data type of the value assigned to the variable, so we need not to declare the variable type beforehand like in other programming languages such as java and c++. For instance take a variable as a locker, then we put in a book, money and probably a football inside , then lets call the book a string, the money an integer and then the football a boolean value showing the different data types in the locker which is the variable, in python we will see that each time we excute the program python automatically detects the data type and prints it according to what its detects as a value, but in java when the variable is defined beforehand as an integer what happens is that if the value stores in the variable is a string, during excution java returns error.
# ## NOTE:
#  In python the value decides the type of variable at that moment, but in java for instance the variable decides what kind of data can be stored.

# %%
##Under dynamic typing, let call the variable item

item = "Book"
print(item)

item = 500
print(item)

item = True
print(item)
# Out:
# Book
# 500
# True

# %%
##Combinning variable reassignment with dynamic typing; this shows different data type in the same variable and returns the new value its detects.

age = 26
age = "Twenty one"
age = 24.5
print(age)
# Out:
# 24.5

# %% [markdown]
# ##Type Conversion;
#  Type conversion is the process of changing value from one data type to another. For example
# 1. A string can become an integer.
# 2. An integer can become a float.
# 3. A float can become a string.

# %%
##Four main types of conversion
# converting from a string to an integer
number = int("30")
print(number)

#converting from a string to a floating-point number
figure = float("150")
print(figure)

# converting from an integer to a string
age = 21
text = str(age)
print(text)

# converting from an integer to a boolean value
is_age = 35
convert = bool(is_age)
print(convert)
print(bool(1))
print(bool(0))

## Type conversion does not change the variable unless you assign the result back
# For instance
age = "35"
print(int(age))

# Note that if the new variable is assigned to the previous variable, the data type changes to the data type it is being converted to for instance

age = 26
converted = str(age)
print(converted)
print(type(converted))
# Out:
# 30
# 150.0
# 21
# True
# True
# False
# 35
# 26
# <class 'str'>

# %%
# why type-conversion is important
age = "30"
added_years = 5
total_years = int(age) + added_years
print(total_years)
# Out:
# 35

# %%
number =  "12"
add_number = 0.5
total = float(number) + add_number
print(total)

days = 100
text = "days"
full_text = str(days) + " " + text
print(full_text)
# Out:
# 12.5
# 100 days

# %% [markdown]
# ## User Input();
#  Input() is a built in function that allows a program to recieve data ftrom user while it is running.
# ## Uses of input:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item

# %%
##Real world example

name = input("Enter your name:")
balance = float(input("Enter your account balance:"))

print("Welcome", name)
print("Your balance is"' \u20A6'+ str(balance))
# Out:
# Enter your name:Tom
# Enter your account balance:45000
# Welcome Tom
# Your balance is ₦45000.0

# %%
##Write a program that asks the user for his name and his current age, then print
## Hello Tom
## Next year you will be 22 years old

name = input("What is your name:")
age = int(input("How old are you:"))
next_age = age + 1
print("Hello", name)
print("Next year you will be",next_age , "years old")
# Out:
# What is your name:Tom
# How old are you:21
# Hello Tom
# Next year you will be 22 years old

# %%
## Write a program that ask the user for his name, his current salary and then increase the salary by 10% then display the result

name = input("Enter your name:")
salary = float(input("Enter your current salary:"))
salary_increment = salary + (0.1 * salary)
print(f"Hello {name}")
print(f"Your new salary is {salary_increment}")
# Out:
# Enter your name:Tom
# Enter your current salary:50000
# Hello Tom
# Your new salary is 55000.0
