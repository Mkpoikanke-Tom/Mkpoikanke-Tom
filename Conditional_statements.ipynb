# %% [markdown]
# <a href="https://colab.research.google.com/github/Mkpoikanke-Tom/Mkpoikanke-Tom/blob/main/Conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Conditional Statement
#  A conditional statement is used to make decision either when a conditions true that is when its just an "if" statement or to execute one block  if the conditon is true or another block if the condition is false
#  ## Different conditional statements includes
#
#
# *   if statement; this is a decision making statement that executes the block of code only when the specified condition is true.
# *   if...else statement;this decision statement  excutes one block of code if the condition is True or another block of code if the conditon is false.
# *   if...elif...else statement; this statement is used when there are multiple conditions to check.Python tests each condition from button to top and excutes only the first condition that is **true**, if none are true its executes the **else** block.
# *   Nested-if-statement;a nested if statement is an if statement inside another if statement. This is when python checks one condition first,if that condition is True it then checks the other conditon inside it.
# Note that every condition end with a colon(:).

# %%
# How if statements work
# if entells "i want to make a decision" after which a comparison operator is being used
# to spell the condition to which the decision is being made.For instance

age = 20
if age >= 18:
  print("You are an adult")        ##python executes the the print statement because the condition here is true
# Out:
# You are an adult

# %%
## what if we had the same variable age with false condition, lets see what python returns

age = 20
if age < 18:
  print("You are an adult")     # We see that python skips the indented line and nothing is printed,
                                # this is where the else condition comes in as returning another block if the condition specified is false

# %%
##Another example of an if condition
marks = 45
if marks >= 50:                            #Python prints the second block because the if condition is false, which thereby passes the indented line
  print("Pass")                            # and prints the second statement. Note that the line printed is outside the if statement.
print("End of program")                    # so it returns whether the condition is true or false




##Important rule
# condition = []
# if condition:
      #Runs only if the condition is true

#This line is outside the if statement above, thus it runs whether the condion is true or false
# Out:
# End of program

# %%
#Another example

age = 20
if age >= 18:
   print("Adult")                #python prints because the if condition is true
   print("Can vote")
   print("Can drive")

print("Program Finished")        # Thus is printed whether the condition is true or not
# Out:
# Adult
# Can vote
# Can drive
# Program Finished

# %%
## If...else statement

age = 16

if age >= 18:                      #Think of this like, if this is true, do this, otherwise do that.
  print("You can vote.")           #Recall earlier that if conditon returns its line when the condition is true,
else:                              #but what happened here is that since the if condition false,python returns another block since the condition is false.
  print("You cannot vote yet.")


# Python syntax
# if condition:
#   prints statement if true
#  else:
#    prints statement if false
# Out:
# You cannot vote yet.

# %%
# Another example
temperature = 18

if temperature > 23:
  print('Hot')
else:
  print("cold")
print("whether checked")
# Out:
# cold
# whether checked

# %%
##Another example
number = 9
if number % 2 == 0:            #this is because python evaluate 9 % 2 == 1, which 1!= 0
  print("Even")
else:
  print("odd")
# Out:
# odd

# %%
age = 15
has_id = True
if age >= 18:
  print("Access Granted")
else:
  print("Access Denied")
print("Security Checked")
# Out:
# Access Denied
# Security Checked

# %%
## if..elif...else statement
# grades for students according to their scores

scores = 65
if scores >= 70:        # False
  print("A")
elif scores >= 60:      # True
  print("B")
elif scores >= 50:      # Not checked, this is because when python finds the true conditon its doesn't evaluate the rest
  print("C")
elif scores >= 40:      # Not checked, python does not evaluate
  print("D")
else:
  print("F")            # Notchecked, python does not evaluate
# Out:
# B

# %%
##The use of input to imput the scores of student manually to generate their grade in an if..elif..else

scores = int(input('"Enter your scores:'))
if scores >= 70:
  print("Your grade is A.")
elif scores >= 60:
  print("Your grade is B.")
elif scores >= 50:
  print("Your grade is C.")
elif scores >= 40:
  print("your grade is D.")
else:
  print("your grade is F.")
# Out:
# "Enter your scores:70
# Your grade is A.

# %%
scores = int(input("Enter your score"))
if scores >= 70:
  print(f"Your score is:{scores}\nYour grade is: A")
elif scores >= 60:
  print(f"Your score is:{scores}\nYour grade is: B")
elif scores >= 50:
  print(f"Your score is:{scores}\nYour grade is: C")
elif scores >= 40:
  print(f"Your score is:{scores}\nYour grade is: D")
else:
  print(f"Your score is:{scores}\nYour grade is: F")
# Out:
# Enter your score70
# Your score is:70
# Your grade is: A

# %%
# FIRST MINI PROJECT ON CONDITIONAL STATEMENT.
# Requirement:The program should ask the user to enter their name; enter their score; print the student name; print the student score;
# print the correct grade, print whether the student passed or failed, where passed = 50 and above and failed = below 50.
# The project done in a more preferred way


name = input("Enter your name: ")
score = int(input("Enter your score: "))
if score >= 70:
      print(f"Student name:{name}\nStudent score:{score}\nGrade: A")
elif score >= 60:
     print(f"Student name:{name}\nStudent score:{score}\nGrade: B")
elif score >= 50:
      print(f"Student name:{name}\nStudent score:{score}\nGrade: C")
elif score >= 40:
      print(f"Student name:{name}\nStudent score:{score}\nGrade: D")
else:
    print(f"Student name:{name}\nStudent score:{score}\nGrade: F")
if score >= 50:
  print(f"Result: Passed")
else:
    print(f"Result: Failed")
# Out:
# Enter your score: 70
# Student name:70
# Student score:70
# Grade: A
# Result: Passed

# %%
##SECOND MINI PROJECT DONE IN CONDITIONAL STATEMENT.

name = input("Enter student name:")
age = int(input("Enter your age:"))
waec = input("Do you have Waec result:")
score = int(input("Enter exam score:"))
if age >= 16 and waec == "yes" and score >= 60:          #Note that at the waec variable it has to be a stringnot a boolean value and to the age and score it was converted
      print(f"Congratulation {name}\nAdmission Granted")   #to an int.
else:
    print(f"sorry {name}.\nAdmission Denied")
# Out:
# Enter student name:Mkpoikanke
# Enter your age:26
# Do you have Waec result:yes
# Enter exam score:211
# Congratulation Mkpoikanke
# Admission Granted

# %% [markdown]
# ## **Logical Operators**
# Logical operators are operators used to modify or combine two or more conditions.They return a Boolean value(True or False).
#
# *   AND operator: the AND operator returns True only when all he conditions being tested are True. this is to say that if any one condition is False, the entire expression becomes false.
# *   OR operator: the OR operator returns True if atleast one of the condition is True. it returns false only when all the conditions are false.
# *   NOT Operator: the NOT operator reverses the Boolean value of a condition. It changes True to False and False to True.
#
# ## Note that:
# Logical operators are often used in conditional statements(if, if...else, if...elif...else and Nested if statements) to evaluate multiple conditions or reverse a condition thereby allowing python to make more complex decisions.

# %%
## Practical examples
# for AND operator

age = 20
has_id = True

if age >= 18 and has_id:     #Python executes the if block since the condition are all true
  print("Entry Allowed")



# OR operator
age = 15
has_permission = True

if age >= 18 or has_permission:    #Python executes the if block since one of the condition is met
  print("Entry Allowed")



# NOT operator
logged_in = False
if not logged_in:              #python executes the if block because the NOT operator reverses the if condition from False to True
  print("Please log in")
# Out:
# Entry Allowed
# Entry Allowed
# Please log in

# %% [markdown]
# ## Capstone Project
#   SCENARIO:
# You have been hired by a university to write a simple admission program,the program should ask;
#
#
# 1.   Student Name.
# 2.   Age.
# 3.   Jamb Score.
# 4.   Has Birth Certificate(yes/no).
#
#   ADMISSION REQUIREMENT
#
#
# *   Age is 16 or above.
# *   Must have waec result.
# *   Jamb score must be 180 or above.
# *   Must have birth certificate.

# %%
name = input("Enter Student Name: ")
age = int(input("Enter Student Age:"))
waec_result = input("Do You Have Waec Result:")
score = int(input("Enter Student Jamb Score:"))
has_birth_certificate = input("Do You Have Birth Certificate:")

if age >= 16 and waec_result == "yes" and score >= 180 and has_birth_certificate == "yes":
    print(f"Congratulations {name}!\nAdmission Granted.")
else:
  print(f"Sorry {name}!\nAdmission Denied")      #Notice that these if statements are inside the else block,the check each admission requirement separately
  if age < 16:                                   #Also every failed condition is printed so that the student knows exactly why the admission was denied.
    print("Your must be atleast 16 years old.")
  if waec_result != "yes":
    print("WAEC result is required.")
  if score < 180:
    print("Jamb score must be atleast 180")
  if has_birth_certificate != "yes":
    print("Birth certificate is required")
# Out:
# Enter Student Name: Mkpoikanke Tom
# Enter Student Age:26
# Do You Have Waec Result:yes
# Enter Student Jamb Score:211
# Do You Have Birth Certificate:yes
# Congratulations Mkpoikanke Tom!
# Admission Granted.

# %%
## duplicate code; let test run the access denied block

name = input("Enter Student Name: ")
age = int(input("Enter Student Age:"))
waec_result = input("Do You Have Waec Result:")
score = int(input("Enter Student Jamb Score:"))
has_birth_certificate = input("Do You Have Birth Certificate:")

if age >= 16 and waec_result == "yes" and score >= 180 and has_birth_certificate == "yes":
    print(f"Congratulations {name}!\nAdmission Granted.")
else:
  print(f"Sorry {name}!\nAdmission Denied")      #Notice that these if statements are inside the else block,the check each admission requirement separately
  if age < 16:                                   #Also every failed condition is printed so that the student knows exactly why the admission was denied.
    print("Your must be atleast 16 years old.")
  if waec_result != "yes":
    print("WAEC result is required.")
  if score < 180:
    print("Jamb score must be atleast 180")
  if has_birth_certificate != "yes":
    print("Birth certificate is required")
# Out:
# Enter Student Name: Mkpoikanke Tom
# Enter Student Age:15
# Do You Have Waec Result:yes
# Enter Student Jamb Score:230
# Do You Have Birth Certificate:no
# Sorry Mkpoikanke Tom!
# Admission Denied
# Your must be atleast 16 years old.
# Birth certificate is required

# %%
## Nested-if statement:A nested if statement is an if statement inside another if statement.The inner if statement is checked if only the outer if condition is True.
# Example
age = 20
has_id = True

if age >= 18:
  print("Age Verified")    #We see that python execute the inner if condition because the outer condition is True,
                           #This means that if the outer condition is not true, python automatically stops, meaning the inner condition even
  if has_id:               # when it is True is not executed.
    print("ID Verified")
print("Finished")
# Out:
# Age Verified
# ID Verified
# Finished

# %%
# Another example
age = 15
has_id = True

if age >= 18:
  print("Age Verified")      # outer condition is false, so python skips the
                             # inner if block.
  if has_id:
    print("ID Verified")

print("Finished")            #Recall the this last statement prints whether the if-statements is true or false.
                             # So the rule here is that the inner if statement is only executed if the outer if statement is True.
# Out:
# Finished

# %%
age = 20
has_id = True
has_ticket = False
if age >= 18:                  #Python executes the first if condition bacause its true
  print("Age Verified")
  if has_id:                    #Python executes the second if condition because it is true
      print("ID Verified")
      if has_ticket:             #python skips the if block because it is false
         print("Enter Concert")
  print("Welcome")               #Python prints this block whether the condition is true or false

print("Finished")                #Python prints this block whether the contion is true or false
# Out:
# Age Verified
# ID Verified
# Welcome
# Finished
